# %% [markdown]
# <a href="https://colab.research.google.com/github/Kmilahiguera/pandas2/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Crear una serie; arreglo unidimsional
#
# se usa la funcion pdc

# %%
miSerie= pd.Series([24,56,78,23,24])
miSerie
# Out:
# 0    24
# 1    56
# 2    78
# 3    23
# 4    24
# dtype: int64

# %% [markdown]
# Diccionarios en python;
#
# Estructura qiue guarda datos en forma de objetos llave - valor

# %%
miDiccionario={
 "nomrbre": "Casa 1",
 "Area:": 120,
 "Baños": 3,
 "Propietarios":[
 "pablo"],
 "Barrio": {
     "nombre:" "camila",
    }
}

miDiccionario
# Out:
# {'nomrbre': 'Casa 1',
#  'Area:': 120,
#  'Baños': 3,
#  'Propietarios': ['pablo'],
#  'Barrio': {'nombre:camila'}}

# %% [markdown]
# La froma simple de crear un diccionario: dataflame
# otra froma puede ser desde una hoja de calculo, desde archis JSON o desde archivos CSV (separados por coma)

# %%
miDataframe= pd.DataFrame({'si': [10,15], 'no': [50,68]})
miDataframe
# Out:
#    si  no
# 0  10  50
# 1  15  68
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['si'].plot(kind='hist', bins=20, title='si')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['no'].plot(kind='hist', bins=20, title='no')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='index', y='si', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_1['si'].plot(kind='hist', bins=20, title='si')
plt.gca().spines[['top', 'right',]].set_visible(False)
